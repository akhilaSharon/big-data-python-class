# %%
from bs4 import BeautifulSoup
import requests
import sys


states_UC = ['AL','AK','AS','AZ','AR','CA','CO','CT','DE',
          'DC','FM','FL','GA','GU','HI','ID','IL','IN','IA',
          'KS','KY','LA','ME','MH','MD','MA','MI','MN','MS',
          'MO','MT','NE','NV','NH','NJ','NM','NY','NC','ND',
          'MP','OH','OK','OR','PW','PA','PR','RI','SC','SD',
          'TN','TX','UT','VT','VI','VA','WA','WV','WI','WY']

states_lc =[]

for x in states_UC:
    lc_state = x.lower()
    states_lc.append(lc_state)


actual_link = 'https://www.areavibes.com/'



for x in states_lc: 
    city_new = []
    
        

    page_link_city = actual_link + x + '/'
    print (page_link_city)
    print(city_new)
    # this is the url that we've already determined is safe and legal to scrape from.
    page_response_city = requests.get(page_link_city, timeout=20)
    
    # here, we fetch the content from the url, using the requests library
    page_content_city = BeautifulSoup(page_response_city.content, "html.parser")
    
    #we use the html parser to parse the url content and store it in a variable.
    
    for i in range(10, 58): 
        anchors = page_content.find_all("a")[i].text
        city_new.append(anchors)
        print (city_new)
#ys.stdout = open('testing','w')
print (city_new)

# %% [markdown]
# ## Connection to PostgreSql

# %%
hostname = 'localhost'
username = 'postgres'
password = 'akhila'
database = 'postgres'
states_list=[]
# Simple routine to run a query on a database and print the results:
def doQuery( conn ) :
    state = input("Please enter your state ")
    cur = conn.cursor()

    cur.execute("SELECT * FROM cities where state_name= '{}'".format(str(state)))

    for city_name,state_name in cur.fetchall() :
        print (city_name)


print ("Using psycopg2…")
import psycopg2
myConnection = psycopg2.connect( host=hostname, user=username, password=password, dbname=database )
doQuery( myConnection )
myConnection.close()
# Out:
# Using psycopg2…
# Please enter your state Texas
# Lubbock
# Texarkana
# The Colony
# Pearland
# Conroe
# San Antonio
# Baytown
# Mission
# Allen
# Abilene
# Wichita Falls
# Missouri City
# Pharr
# Midland
# Rockwall
# DeSoto
# Bedford
# Harlingen
# Denton
# Galveston
# Laredo
# Haltom City
# Sugar Land
# Duncanville
# Lancaster
# Weslaco
# San Angelo
# Rowlett
# North Richland Hills
# Dallas
# McAllen
# McKinney
# Killeen
# Amarillo
# Longview
# Grand Prairie
# Mesquite
# Garland
# Port Arthur
# Burleson
# Richardson
# San Marcos
# Frisco
# New Braunfels
# Irving
# Houston
# Beaumont
# Odessa
# Georgetown
# Keller
# Euless
# Pasadena
# El Paso
# Edinburg
# Texas City
# Temple
# Pflugerville
# Victoria
# Wylie
# Carrollton
# Huntsville
# Round Rock
# Friendswood
# Cedar Park
# Bryan
# Hurst
# Plano
# Coppell
# College Station
# Sherman
# Fort Worth
# Tyler
# Waco
# Arlington
# Lewisville
# League City
# Cedar Hill
# Corpus Christi
# Brownsville
# Flower Mound
# Grapevine
# Mansfield
# ...

# %%
hostname = 'localhost'
username = 'postgres'
password = 'akhila'
database = 'postgres'

# Simple routine to run a query on a database and print the results:
def doQuery( conn ) :
    state = input("Please enter your state ")
    cur = conn.cursor()

    cur.execute("SELECT * FROM cities where state_name= '{}'".format(str(state)))
    print ("The cities in", state, "are")
    for city_name,state_name in cur.fetchall() :
        print (city_name)



import psycopg2
myConnection = psycopg2.connect( host=hostname, user=username, password=password, dbname=database )
doQuery( myConnection )
myConnection.close()
# Out:
# Please enter your state Alabama
# The cities in Alabama are
# Huntsville
# Madison
# Montgomery
# Mobile
# Tuscaloosa
# Hoover
# Decatur
# Auburn
# Florence
# Phenix City
# Dothan
# Birmingham

# %%
pageTemplate = '''
<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
<html>
<head>
  <meta content="text/html; charset=ISO-8859-1"
 http-equiv="content-type">
  <title>Hello</title>
</head>
<body>
Hello, {person}!
</body>
</html>''' # NEW note '{person}' two lines up

def main():    # NEW
    person = input("Enter a name: ")  
    contents = pageTemplate.format(**locals())   
    browseLocal(contents)
    
main()
# Out:
# Enter a name: Akhila

# %%
import tkinter # note that module name has changed from Tkinter in Python 2 to tkinter in Python 3
top = tkinter.Tk()
# Code to add widgets will go here...
top.mainloop()

# %%
from tkinter import *

class Window(Frame):


    def __init__(self, master=None):
        Frame.__init__(self, master)                 
        self.master = master
        self.init_window()

    #Creation of init_window
    def init_window(self):

        # changing the title of our master widget      
        self.master.title("GUI")

        # allowing the widget to take the full space of the root window
        self.pack(fill=BOTH, expand=1)

        # creating a button instance
        quitButton = Button(self, text="Quit")

        # placing the button on my window
        quitButton.place(x=0, y=0)

root = Tk()

#size of the window
root.geometry("400x300")

app = Window(root)
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-d623969a804f> in <module>()
#       1 from tkinter import *
#       2 import tkinter as ttk
# ----> 3 from tk import *
#       4
#       5 root = Tk()
#
# ModuleNotFoundError: No module named 'tk'

# %%
import tkinter as tk


hostname = 'localhost'
username = 'postgres'
password = 'akhila'
database = 'postgres'

OptionList = [] 
# Simple routine to run a query on a database and print the results:
def doQuery( conn ) :
    #state = input("Please enter your state ")
    cur = conn.cursor()

    cur.execute("SELECT DISTINCT state_name FROM cities ORDER BY state_name")

    for state_name in cur.fetchall() :
        OptionList.append(state_name)


import psycopg2

myConnection = psycopg2.connect( host=hostname, user=username, password=password, dbname=database )
doQuery( myConnection )
myConnection.close()



app = tk.Tk()

app.geometry('400x400')

variable = tk.StringVar(app)
variable.set(OptionList[0])

opt = tk.OptionMenu(app, variable, *OptionList)
opt.config(width=90, font=('Helvetica', 12))
opt.pack()

app.mainloop()

# %%
hostname = 'localhost'
username = 'postgres'
password = 'akhila'
database = 'postgres'

state_list =[]
# Simple routine to run a query on a database and print the results:
def doQuery( conn ) :
    #state = input("Please enter your state ")
    cur = conn.cursor()

    cur.execute("SELECT DISTINCT state_name FROM cities ORDER BY state_name")

    for state_name in cur.fetchall() :
        print (state_name)


import psycopg2

myConnection = psycopg2.connect( host=hostname, user=username, password=password, dbname=database )
doQuery( myConnection )
myConnection.close()
# Out:
# ('Alabama',)
# ('Alaska',)
# ('Arizona',)
# ('Arkansas',)
# ('California',)
# ('Colorado',)
# ('Connecticut',)
# ('Delaware',)
# ('District of Columbia',)
# ('Florida',)
# ('Georgia',)
# ('Hawaii',)
# ('Idaho',)
# ('Illinois',)
# ('Indiana',)
# ('Iowa',)
# ('Kansas',)
# ('Kentucky',)
# ('Louisiana',)
# ('Maine',)
# ('Maryland',)
# ('Massachusetts',)
# ('Michigan',)
# ('Minnesota',)
# ('Mississippi',)
# ('Missouri',)
# ('Montana',)
# ('Nebraska',)
# ('Nevada',)
# ('New Hampshire',)
# ('New Jersey',)
# ('New Mexico',)
# ('New York',)
# ('North Carolina',)
# ('North Dakota',)
# ('Ohio',)
# ('Oklahoma',)
# ('Oregon',)
# ('Pennsylvania',)
# ('Rhode Island',)
# ('South Carolina',)
# ('South Dakota',)
# ('Tennessee',)
# ('Texas',)
# ('Utah',)
# ('Vermont',)
# ('Virginia',)
# ('Washington',)
# ('West Virginia',)
# ('Wisconsin',)
# ('Wyoming',)

# %%
from tkinter import *
from tkinter.ttk import *

class Gui:

    def __init__(self):
        self.root = Tk()

        # Set up the Combobox
        self.selections = Combobox(self.root)
        self.selections['values'] = ["Alabama","Alaska","Arizona","Arkansas","California","Colorado",
  "Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois",
  "Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
  "Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana",
  "Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York",
  "North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania",
  "Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah",
  "Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"]
        self.selections.pack()

        # The Entry to be shown if "Custom" is selected
        self.custom_field = Entry(self.root)
        self.show_custom_field = False

        # Check the selection in 100 ms
        self.root.after(100, self.check_for_selection)
        print ("value is", self.selections.get())
        
        #w = Label(self.root, text=value) 
       # w.pack()
        

    def check_for_selection(self):
        '''Checks if the value of the Combobox equals "Custom".'''


        # Get the value of the Combobox
        value = self.selections.get()

        # If the value is equal to "Custom" and show_field is set to False
        if value == 'Custom' and not self.show_custom_field:

            # Set show_field to True and pack() the custom entry field
            self.show_custom_field = True
            self.custom_field.pack()


        # If the value DOESNT equal "Custom"
        elif value != 'Custom':

            # Set show_field to False
            self.show_custom_field = False

            # Destroy the custom input
            self.custom_field.destroy()

            # Set up a new Entry object to pack() if we need it later.
            # Without this line, tkinter was raising an error for me.
            # This fixed it, but I don't promise that this is the
            # most efficient method to do this.
            self.custom_field = Entry(self.root)

        # If the value IS "Custom" and we're showing the custom_feild
        elif value == 'Custom' and self.show_custom_field:
            pass


        # Call this method again to keep checking the selection box
        self.root.after(100, self.check_for_selection)
        




app = Gui()
app.root.geometry('400x400')
app.root.mainloop()
# Out:
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# value is
# ...

# %%
import requests
import pandas as pd

business_id= "ACFtxLv8pGrrxMm6EgjreA"

def run_query(): # A simple function to use requests.post to make the API call. Note the json= section.
    
    query = """
{
    reviews(business: \""""  + str(business_id)+ """\"){
        total
        review {
            text
        }
    }
}
"""  
    headers = {"Authorization": "Bearer oPZxFSVSMStojf1HGATF-HqDIvnUVNF8rLZ6CV3x3RsUawatli5rUlzOz9wBQ6mbwJ4wV5LqMCgVmx_DDd-PwGbLKZ73m3yT5IOQv-iwXETNgwwrIdMRSVhXwLtlXHYx"}
    url = 'https://api.yelp.com/v3/graphql'
    request = requests.post(url, json={'query': query}, headers=headers)
    #if request.status_code == 200:
    reply = request.json()
    review = reply["data"]["reviews"]["review"]
    return review
    #else:
     #   raise Exception("Query failed to run by returning code of {}. {}".format(request.status_code, query))

        
# The GraphQL query (with a few aditional bits included) itself defined as a multi-line string.       

result = run_query()
df = pd.DataFrame(result) 
df
# Out:
#                                                 text
# 0  This is probably my favorite restaurant in Mon...
# 1  It's been about 3 years since I ate here and I...
# 2  My favourite burger in Montreal (and, conseque...

# %%
import requests
import pandas as pd

bid= "S8urdN6ACnRQUm-7o9An8w"

def run_query(business_id): # A simple function to use requests.post to make the API call. Note the json= section.
    
    query = """
{
    reviews(business: \""""  + str(business_id)+ """\"){
        total
        review {
            text
        }
    }
}
"""  
    headers = {"Authorization": "Bearer oPZxFSVSMStojf1HGATF-HqDIvnUVNF8rLZ6CV3x3RsUawatli5rUlzOz9wBQ6mbwJ4wV5LqMCgVmx_DDd-PwGbLKZ73m3yT5IOQv-iwXETNgwwrIdMRSVhXwLtlXHYx"}
    url = 'https://api.yelp.com/v3/graphql'
    request = requests.post(url, json={'query': query}, headers=headers)
    #if request.status_code == 200:
    reply = request.json()
    review = reply["data"]["reviews"]["review"]
    return review
    #else:
     #   raise Exception("Query failed to run by returning code of {}. {}".format(request.status_code, query))

        
# The GraphQL query (with a few aditional bits included) itself defined as a multi-line string.       

result = run_query(bid)
result
# Out:
# [{'text': "This is a favorite spot for sunset dining. You'll want reservations well in advance. It's right next to the Duquesne incline so the view and the popularity..."},
#  {'text': 'Went again for anniv w my SO-- \n1. Food quantities were larger and slightly lower quality but still delicious and extremely good by pgh standards\n2. Dessert...'},
#  {'text': 'I have to say as soon as you walk into Altius you know you are getting a one-of-a-kind dining experience with welcoming staff. My wife and I went for our...'}]

# %%
#!/usr/bin/env python
"""
convert dos linefeeds (crlf) to unix (lf)
usage: dos2unix.py 
"""
original = ".\data\menu_list.pkl"
destination = ".\data\menu_list_mod.pkl"
content = ''
outsize = 0
with open(original, 'rb') as infile:
    content = infile.read()
with open(destination, 'wb') as output:
    for line in content.splitlines():
        outsize += len(line) + 1
        output.write(line + str.encode('\n'))
print("Done. Saved %s bytes." % (len(content)-outsize))
# Out:
# Done. Saved 21364 bytes.

# %%
import pandas as pd
import csv
from six.moves import cPickle as pickle
import numpy as np

# %%
main_food_df = pd.read_pickle(".\data\word_list_mod.pkl") #load common food
menu_list_prep = pd.read_pickle(".\data\menu_list_mod.pkl") #load menu list

# %%
menu_prep_two =[name[:-1] if name.endswith('\r')  else name for name in menu_list_prep] #clean the unwanted data
import unicodedata

menu_prep_three_df = [x.encode('UTF8') for x in menu_prep_two]

# %%
from __future__ import unicode_literals
menu_d_df=[]
for item in menu_prep_three_df:
    if len(item.split()) < 3:
        menu_d_df.append(item)

# %%
import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
import spacy
import en_core_web_sm
from spacy.matcher import PhraseMatcher
from spacy.tokens import Span


nlp = en_core_web_sm.load() 
patterns = [nlp(item.decode('utf8')) for item in  main_food_df]  # process each word to create phrase pattern
matcher = PhraseMatcher(nlp.vocab)
matcher.add('MAIN FOOD', None, *patterns)  # add patterns to matcher
patternstwo = [nlp(itemtwo.decode('utf8')) for itemtwo in menu_d_df]  # process each word to create phrase pattern
matcher = PhraseMatcher(nlp.vocab)
matcher.add('IN MENU', None, *patternstwo)  # add patterns to matcher

doc = nlp("I love the Asparagus Prawn from this place")
matches = matcher(doc)

for match_id, start, end in matches:
    # create a new Span for each match and use the match_id  as the label
    span = Span(doc, start, end, label=match_id)
    doc.ents = list(doc.ents) + [span]  # add span to doc.ents

print([(ent.text, ent.label_) for ent in doc.ents])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-d35082a3893f> in <module>()
#       6
#       7 nlp = en_core_web_sm.load()
# ----> 8 patterns = [nlp(item.decode('utf8')) for item in  main_food_df]  # process each word to create phrase pattern
#       9 matcher = PhraseMatcher(nlp.vocab)
#      10 matcher.add('MAIN FOOD', None, *patterns)  # add patterns to matcher
#
# <ipython-input-63-d35082a3893f> in <listcomp>(.0)
#       6
#       7 nlp = en_core_web_sm.load()
# ----> 8 patterns = [nlp(item.decode('utf8')) for item in  main_food_df]  # process each word to create phrase pattern
#       9 matcher = PhraseMatcher(nlp.vocab)
#      10 matcher.add('MAIN FOOD', None, *patterns)  # add patterns to matcher
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
import requests
import pandas as pd
business_id= "ACFtxLv8pGrrxMm6EgjreA"
def run_query(): # A simple function to use requests.post to make the API call. Note the json= section.
    
    query = """
{
    reviews(business: \""""  + str(business_id)+ """\"){
        total
        review {
            text
        }
    }
}
"""  
    headers = {"Authorization": "Bearer oPZxFSVSMStojf1HGATF-HqDIvnUVNF8rLZ6CV3x3RsUawatli5rUlzOz9wBQ6mbwJ4wV5LqMCgVmx_DDd-PwGbLKZ73m3yT5IOQv-iwXETNgwwrIdMRSVhXwLtlXHYx"}
    url = 'https://api.yelp.com/v3/graphql'
    request = requests.post(url, json={'query': query}, headers=headers)
    #if request.status_code == 200:
    reply = request.json()
    review = reply["data"]["reviews"]["review"]
    return review
result = run_query()
df = pd.DataFrame(result) 
df
# Out:
#                                                 text
# 0  One of my first choice to go to after work. Ch...
# 1  It's been about 3 years since I ate here and I...
# 2  we come here at late noon time, even I knoe it...

# %%
import pandas as pd
final_review = pd.read_csv("finalresult.csv", nrows=10)
final_review.head()
# Out:
#    s_no      rating               food_item  \
# 0     1  V.Negative          calamari rings
# 1     2  V.Negative  chicken parm meatballs
# 2     3    Negative                   pasta
#
#                                              reviews
# 0  We were waiting 50 min for entrees. Got overco...
# 1  The dishes we had were served barely warm whic...
# 2  The food is just awful. Pasta was served in a ...
