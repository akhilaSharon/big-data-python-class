# %% [markdown]
# ## Homework 3.1
#
# ### 3.1.a
# Load the data from: http://opendata.dc.gov/datasets that I have include in this github
# into a dataframe.  ( The file has been is available in directory ./data/ccp_current_csv.csv )

# %%
import pandas as pd
import numpy as np
myfile=pd.read_csv("./data/ccp_current_csv.csv")
myfile.head()
# Out:
#              STREET QUADRANT  FROMINTERSECTION              TOINTERSECTION  \
# 0           13th St       NW        Kennedy St               Longfellow St
# 1              S St       NW  North Capitol St                      3rd St
# 2  Rhode Island Ave       NE  Brentwood Rd (W)            Brentwood Rd (M)
# 3           Mill Rd       NW           27th St                  Cul De Sac
# 4  Rhode Island Ave       NE  Brentwood Rd (M)  14th St  Evarts St  Montan
#
#    NOOFBLOCKS                 WORKDESCRIPTION  YEARBUDGETED  PERCENTCOMPLETED  \
# 0           1  Pavement Resurface/restoration          2004               100
# 1           3                   Regular Cover          1999               100
# 2           1  Pavement Resurface/restoration          2004               100
# 3           1  Pavement Resurface/restoration          2004               100
# 4           2  Pavement Resurface/restoration          2005               100
#
# ...

# %% [markdown]
# ### 3.1.a  what is its shape and what does that mean?

# %%
shape_of_file = myfile.shape
print(shape_of_file)
print(type(shape_of_file))
#shape returns a tuple representing the dimensionality of the DataFrame.
#It means there are 465 rows and 27 columns
# Out:
# (465, 27)
# <type 'tuple'>

# %% [markdown]
# ## Homework 3.2
#  What are the number of rows in each 'QUADRANT' ?

# %%
print(len(myfile.index))
#there are 465 number of rows
myfile['QUADRANT'].value_counts()
#returns count(number of rows) in each Quadrant
# Out:
# 465
# NW    195
# NE    163
# SE     84
# BN     12
# SW     11
# Name: QUADRANT, dtype: int64

# %% [markdown]
# ## Homework 3.3 - Array math demonstration
# For two arrarys
#
# a= [1,2,3,4]  type=float
#
# b= [5,6,7,8]  type=float
#
# Peform the following array operations using numpy
# ( show both operational use of numpy and functional (example addition operation => + vs addition function => numbpy.add() )
#
# ### 3.3.1 addition a+b

# %%
a = np.array([1,2,3,4],dtype=float)
b = np.array([5,6,7,8],dtype=float)
print (a+b) # addition operation
print (np.add(a,b)) # add function
# Out:
# [ 6.  8. 10. 12.]
# [ 6.  8. 10. 12.]

# %% [markdown]
# ### 3.3.2 subtraction a-b

# %%
print (a-b)  #subtraction operation
print(np.subtract(a,b)) # subtract function
# Out:
# [-4. -4. -4. -4.]
# [-4. -4. -4. -4.]

# %% [markdown]
# ### 3.3.3 multiplication a*b

# %%
print(a*b) # multiplication operation
print(np.multiply(a,b)) #multiply funcction
# Out:
# [ 5. 12. 21. 32.]
# [ 5. 12. 21. 32.]

# %% [markdown]
# ### 3.3.4 divsion a/b

# %%
print(a/b) # division operation
print(np.divide(a,b)) #divide function
# Out:
# [0.2        0.33333333 0.42857143 0.5       ]
# [0.2        0.33333333 0.42857143 0.5       ]

# %% [markdown]
# ### 3.3.5 modulo  a%b

# %%
print(a%b) #modulo operation
print(np.mod(a,b)) # mod function
# Out:
# [1. 2. 3. 4.]
# [1. 2. 3. 4.]

# %% [markdown]
# ### 3.3.6 power  a^b

# %%
print(a**b) #power operation
print(np.power(a,b)) #power function
# Out:
# [1.0000e+00 6.4000e+01 2.1870e+03 6.5536e+04]
# [1.0000e+00 6.4000e+01 2.1870e+03 6.5536e+04]

# %% [markdown]
# ### 3.3.7 Other functions

# %% [markdown]
# #### Absolute function
# This mathematical function helps user to calculate absolute value of each element.

# %%
np.absolute(a)
# Out:
# array([1., 2., 3., 4.])

# %% [markdown]
# #### Trigonometric functions

# %%
print(np.sin(a))
print(np.cos(a))
print(np.tan(a))
# Out:
# [ 0.84147098  0.90929743  0.14112001 -0.7568025 ]
# [ 0.54030231 -0.41614684 -0.9899925  -0.65364362]
# [ 1.55740772 -2.18503986 -0.14254654  1.15782128]

# %% [markdown]
# #### Exponents and logarithms

# %%
print("b    =", b)
print("e^b  =", np.exp(b))
print("2^b   =", np.exp2(b))
print("3^b  =", np.power(3, b))
print("ln(b)    =", np.log(b))
print("log2(b)  =", np.log2(b))
print("log10(b) =", np.log10(b))
# Out:
# ('b    =', array([5., 6., 7., 8.]))
# ('e^b  =', array([ 148.4131591 ,  403.42879349, 1096.63315843, 2980.95798704]))
# ('2^b   =', array([ 32.,  64., 128., 256.]))
# ('3^b  =', array([ 243.,  729., 2187., 6561.]))
# ('ln(b)    =', array([1.60943791, 1.79175947, 1.94591015, 2.07944154]))
# ('log2(b)  =', array([2.32192809, 2.5849625 , 2.80735492, 3.        ]))
# ('log10(b) =', array([0.69897   , 0.77815125, 0.84509804, 0.90308999]))

# %% [markdown]
# #### Aggregate functions
#
# ##### Reduce function
# A reduce repeatedly applies a given operation to the elements of an array until only a single result remains.

# %%
np.add.reduce(b)
# Out:
# 26.0

# %%
np.multiply.reduce(b)
# Out:
# 1680.0

# %% [markdown]
# #####  Accumulate Function
# This function is used to Accumulate the result of applying the operator to all elements.

# %%
np.add.accumulate(a)
# Out:
# array([ 1.,  3.,  6., 10.])

# %% [markdown]
# #### Outer products
# This allows you, in one line, to do things like create a multiplication table.

# %%
np.multiply.outer(a,b)
# Out:
# array([[ 5.,  6.,  7.,  8.],
#        [10., 12., 14., 16.],
#        [15., 18., 21., 24.],
#        [20., 24., 28., 32.]])

# %% [markdown]
# #### Scalar Product / Dot Product
# This function returns the dot product of two arrays. For 2-D vectors, it is the equivalent to matrix multiplication. For 1-D arrays, it is the inner product of the vectors. For N-dimensional arrays, it is a sum product over the last axis of a and the second-last axis of b.

# %%
dot =np.dot(a,b)
dot
# Out:
# 70.0

# %%
a_modulus = np.sqrt((a*a).sum())
b_modulus = np.sqrt((b*b).sum())
cos_angle = dot / a_modulus / a_modulus # returns cosine of angle between a and b
cos_angle
# Out:
# 2.3333333333333335

# %% [markdown]
# #### Pi

# %%
cos_angle * 360 / 2 / np.pi # returns angle in degrees
# Out:
# 133.69015219719208

# %% [markdown]
# #### Cross product
# This function returns the cross product of two arrays.

# %%
x = np.array([0,0,1])
y = np.array([0,1,0])
np.cross(x,y)
# Out:
# array([-1,  0,  0])

# %%
np.cross(y,x)
# Out:
# array([1, 0, 0])

# %% [markdown]
# ## Boolean Indexing of Array

# %%
A = np.array([2,6,1,8,4,1,0])
print(A == 1)
print(A > 5)
# Out:
# [False False  True False False  True False]
# [False  True False  True False False False]

# %%
#also works on higher dimensions

B = np.array([[4,56,89,65],
              [99,88,36,12],
              [55,92,7,18]])
print(B>=42)
# Out:
# [[False  True  True  True]
#  [ True  True False False]
#  [ True  True False False]]

# %% [markdown]
# ### Fancy Indexing
# If arrays are indexed by using boolean or integer arrays (masks). The result will be a copy and not a view.

# %%
C = np.array([123,188,190,99,77,88,100])
A = np.array([4,7,2,8,6,9,5])
R = C[A<=5]
print(R)
## Indexing with an Integer Array
print(C[[0, 2, 3, 1, 4, 1]])
# Out:
# [123 190 100]
# [123 190  99 188  77 188]

# %% [markdown]
# ### Non zero
# an ndarray a both numpy.nonzero(a) and a.nonzero() return the indices of the elements of a that are non-zero. The indices are returned as a tuple of arrays, one for each dimension of 'a'. The corresponding non-zero values can be obtained

# %%
nz = np.array([[0, 2, 3, 0, 1],
              [1, 0, 0, 7, 0],
              [5, 0, 0, 1, 0]])
print(nz.nonzero())

#If you want to group the indices by element, you can use transpose :transpose(nonzero(nz))
np.transpose(nz.nonzero())
# Out:
# (array([0, 0, 0, 1, 1, 2, 2], dtype=int64), array([1, 2, 4, 0, 3, 0, 3], dtype=int64))
# array([[0, 1],
#        [0, 2],
#        [0, 4],
#        [1, 0],
#        [1, 3],
#        [2, 0],
#        [2, 3]], dtype=int64)

# %% [markdown]
# The function 'nonzero' can be used to obtain the indices of an array, where a condition is True. In the following script, we create the Boolean array B >= 42

# %%
B = np.array([[42,56,89,65],
              [99,88,42,12],
              [55,42,17,18]])
print(B >= 42)
# Out:
# [[ True  True  True  True]
#  [ True  True  True False]
#  [ True  True False False]]

# %% [markdown]
# ## Homework 3.4
# Find your own data and load it into a dataframe

# %%
# the dataset was downloaded from https://www.kaggle.com/davidrgp/pokedex

poke_data = pd.read_csv("./data/pokemon.csv")
poke_data.head()
# Out:
#    id     pokemon  species_id  height  weight  base_experience type_1  type_2  \
# 0   1   bulbasaur           1       7      69               64  grass  poison
# 1   2     ivysaur           2      10     130              142  grass  poison
# 2   3    venusaur           3      20    1000              236  grass  poison
# 3   4  charmander           4       6      85               62   fire     NaN
# 4   5  charmeleon           5      11     190              142   fire     NaN
#
#    attack  defense    ...      color_2  color_f  egg_group_1  egg_group_2  \
# 0      49       49    ...      #A040A0  #81A763      monster        plant
# 1      62       63    ...      #A040A0  #81A763      monster        plant
# 2      82       83    ...      #A040A0  #81A763      monster        plant
# 3      52       43    ...          NaN      NaN      monster       dragon
# 4      64       58    ...          NaN      NaN      monster       dragon
#
# ...

# %% [markdown]
# ## Homework 3.5
# Provide an interesting analysis of the data columns ( frequency or averages )

# %%
# check the data frame info
print(poke_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 811 entries, 0 to 810
# Data columns (total 28 columns):
# id                         811 non-null int64
# pokemon                    811 non-null object
# species_id                 811 non-null int64
# height                     811 non-null int64
# weight                     811 non-null int64
# base_experience            811 non-null int64
# type_1                     811 non-null object
# type_2                     414 non-null object
# attack                     811 non-null int64
# defense                    811 non-null int64
# hp                         811 non-null int64
# special_attack             811 non-null int64
# special_defense            811 non-null int64
# speed                      811 non-null int64
# ability_1                  811 non-null object
# ability_2                  402 non-null object
# ability_hidden             654 non-null object
# color_1                    811 non-null object
# ...

# %% [markdown]
# value_counts() - Returns object containing counts of unique values.

# %%
poke_data['type_1'].value_counts()

#value_counts will return NumPy array with unique items and the frequency of it.
# Out:
# water       114
# normal       98
# grass        70
# bug          69
# psychic      57
# fire         53
# electric     50
# rock         44
# dragon       32
# ground       32
# ghost        32
# dark         31
# poison       28
# fighting     27
# steel        27
# ice          25
# fairy        18
# flying        4
# Name: type_1, dtype: int64

# %%
len(poke_data)
# returns the number of rows
# Out:
# 811

# %% [markdown]
# ### Simple Aggregation in Pandas
# - count()	-Total number of items
# - first(), last()	-First and last item
# - mean(), median()	-Mean and median
# - min(), max()	-Minimum and maximum
# - std(), var()-	Standard deviation and variance
# - mad()	-Mean absolute deviation
# - prod()-	Product of all items
# - sum()	-Sum of all items

# %%
poke_data.count()
# returns number of non-NA elements in a Series
# Out:
# id                         811
# pokemon                    811
# species_id                 811
# height                     811
# weight                     811
# base_experience            811
# type_1                     811
# type_2                     414
# attack                     811
# defense                    811
# hp                         811
# special_attack             811
# special_defense            811
# speed                      811
# ability_1                  811
# ability_2                  402
# ability_hidden             654
# color_1                    811
# color_2                    414
# color_f                    414
# egg_group_1                811
# egg_group_2                216
# url_image                  718
# generation_id              721
# evolves_from_species_id    355
# evolution_chain_id         721
# shape_id                   721
# shape                      721
# dtype: int64

# %%
count_of_nan = len(poke_data) - poke_data.count()
print(count_of_nan)
#returns the number of missing elements in each coloumn
# Out:
# id                           0
# pokemon                      0
# species_id                   0
# height                       0
# weight                       0
# base_experience              0
# type_1                       0
# type_2                     397
# attack                       0
# defense                      0
# hp                           0
# special_attack               0
# special_defense              0
# speed                        0
# ability_1                    0
# ability_2                  409
# ability_hidden             157
# color_1                      0
# color_2                    397
# color_f                    397
# egg_group_1                  0
# egg_group_2                595
# url_image                   93
# generation_id               90
# evolves_from_species_id    456
# evolution_chain_id          90
# shape_id                    90
# shape                       90
# dtype: int64

# %%
# returns the heaviest pokemon

heavy_poke = poke_data['weight'].max()

poke_data.loc[poke_data['weight'] == heavy_poke]
# Out:
#         id         pokemon  species_id  height  weight  base_experience  \
# 798  10078  groudon-primal         383     500    9997              347
#
#      type_1 type_2  attack  defense  ...   color_2  color_f  egg_group_1  \
# 798  ground   fire     180      160  ...   #F08030  #E3B05A      no-eggs
#
#      egg_group_2 url_image generation_id evolves_from_species_id  \
# 798          NaN       NaN           NaN                     NaN
#
#     evolution_chain_id shape_id shape
# 798                NaN      NaN   NaN
#
# [1 rows x 28 columns]

# %%
# returns the tallest pokemon

tall_poke = poke_data['height'].max()

poke_data.loc[poke_data['height'] == tall_poke]
# Out:
#         id        pokemon  species_id  height  weight  base_experience  \
# 799  10079  rayquaza-mega         384    1080    3920              351
#
#      type_1  type_2  attack  defense  ...   color_2  color_f  egg_group_1  \
# 799  dragon  flying     180      100  ...   #A890F0  #7D4DF6      no-eggs
#
#      egg_group_2 url_image generation_id evolves_from_species_id  \
# 799          NaN       NaN           NaN                     NaN
#
#     evolution_chain_id shape_id shape
# 799                NaN      NaN   NaN
#
# [1 rows x 28 columns]

# %%
# to find the mean and median of the height
poke_data['height'].mean()
# Out:
# 20.384710234278668

# %%
# returns the pokemons whose height is same as the median of the heights
poke_data.loc[poke_data['height'] == poke_data['height'].median()]
# Out:
#         id                pokemon  species_id  height  weight  \
# 1        2                ivysaur           2      10     130
# 7        8              wartortle           8      10     225
# 14      15               beedrill          15      10     295
# 27      28              sandslash          28      10     295
# 39      40             wigglytuff          40      10     120
# 46      47               parasect          47      10     295
# 47      48                venonat          48      10     300
# 52      53                persian          53      10     320
# 56      57               primeape          57      10     320
# 60      61              poliwhirl          61      10     200
# 69      70             weepinbell          70      10      64
# 74      75               graveler          75      10    1050
# 76      77                 ponyta          77      10     300
# 81      82               magneton          82      10     600
# ...

# %% [markdown]
# ### GroupBy: Split, Apply, Combine

# %%
#Groupby on type_1 and sort by height in decending order.

c = poke_data.groupby('type_1').sum()
c = c.sort_values(['height'], ascending=False)
c
# Out:
#               id  species_id  height  weight  base_experience  attack  \
# type_1
# water     122532       34847    3115   68812            16536    8467
# dragon     92054       15180    2028   41501             7182    3588
# steel      60362       11957    1697   56062             5025    2503
# normal     79826       31279    1439   42316            14197    7200
# psychic   118388       21706    1378   23852            10376    4073
# grass      63096       24141     894   29161            10148    5125
# ground     30472       11401     875   42095             4751    3064
# fire       76114       17376     865   36841             8628    4478
# bug        81918       23080     746   21428             8577    4897
# rock       46337       17280     699   44929             6458    4086
# electric  153131       16144     639   15521             7670    3370
# ice        29892       10516     491   27260             3758    1816
# ...

# %% [markdown]
# As with the GroupBy object, no computation is done until we call some aggregate on the object:

# %%
poke_data.groupby('type_2')['weight']

# %%
poke_data.groupby('type_2')['weight'].median()
# Out:
# type_2
# bug          125.0
# dark         694.5
# dragon       835.0
# electric     131.5
# fairy        115.0
# fighting     520.0
# fire         315.5
# flying       280.0
# ghost        298.0
# grass        125.0
# ground       620.0
# ice         1340.0
# normal       172.5
# poison       127.5
# psychic      600.0
# rock         705.0
# steel        650.0
# water        332.5
# Name: weight, dtype: float64

# %% [markdown]
# ### Iteration over groups
# The GroupBy object supports direct iteration over the groups, returning each group as a Series or DataFrame

# %%
for (method, group) in poke_data.groupby('type_2'):
    print("{0:30s} shape={1}".format(method, group.shape))
# Out:
# bug                            shape=(3, 28)
# dark                           shape=(20, 28)
# dragon                         shape=(18, 28)
# electric                       shape=(6, 28)
# fairy                          shape=(23, 28)
# fighting                       shape=(26, 28)
# fire                           shape=(12, 28)
# flying                         shape=(97, 28)
# ghost                          shape=(14, 28)
# grass                          shape=(25, 28)
# ground                         shape=(35, 28)
# ice                            shape=(14, 28)
# normal                         shape=(4, 28)
# poison                         shape=(34, 28)
# psychic                        shape=(33, 28)
# rock                           shape=(14, 28)
# steel                          shape=(22, 28)
# water                          shape=(14, 28)

# %% [markdown]
# ### Dispatch methods
# We can use the describe() method of DataFrames to perform a set of aggregations that describe each group in the data.

# %%
poke_data.groupby('type_2')['weight'].describe().unstack()
# Out:
#        type_2
# count  bug            3.000000
#        dark          20.000000
#        dragon        18.000000
#        electric       6.000000
#        fairy         23.000000
#        fighting      26.000000
#        fire          12.000000
#        flying        97.000000
#        ghost         14.000000
#        grass         25.000000
#        ground        35.000000
#        ice           14.000000
#        normal         4.000000
#        poison        34.000000
#        psychic       33.000000
#        rock          14.000000
#        steel         22.000000
#        water         14.000000
# mean   bug          309.000000
#        dark        1118.650000
#        dragon      1996.277778
#        electric     675.666667
#        fairy        169.956522
#        fighting     727.730769
#        fire        1295.416667
#        flying       479.845361
#        ghost        651.142857
#        grass        218.920000
#        ground      1258.428571
# ...

# %% [markdown]
# ### Aggregation
# aggregate() can take a string, a function, or a list thereof, and compute all the aggregates at once.

# %%
poke_data.groupby('type_2').aggregate([min, np.median, max])
# Out:
#            id               species_id             height              weight  \
#           min median    max        min median  max    min median   max    min
# type_2
# bug       347  348.0    451        347  348.0  451      7    8.0    15    120
# dark      248  447.0  10086        130  388.0  720      4   13.0   650    152
# dragon    230  663.0  10065          6  487.0  715      5   18.0   190     80
# electric  170  595.5    644        170  595.5  644      1    7.5    29      6
# fairy      39  439.0  10075         39  303.0  719      2    7.0   150      6
# fighting   62  559.5  10088         62  464.5  652      6   14.5   160     65
# fire      228  622.5  10078        228  550.5  643      3   10.5   500      3
# flying      6  373.0  10089          6  291.0  717      2   12.0  1080      3
# ghost     292  622.5  10066        292  607.5  720      3   11.0    50      3
# grass      46  585.0  10032         46  542.0  711      3    7.0    19      3
# ...

# %% [markdown]
# Another useful pattern is to pass a dictionary mapping column names to operations to be applied on that column.

# %%
#returns the type of pokemon with minimum height and maximum weight
poke_data.groupby('type_2').aggregate({'height': 'min',
                             'weight': 'max'})
# Out:
#           weight  height
# type_2
# bug          682       7
# dark        4900       4
# dragon      7500       5
# electric    3450       1
# fairy        545       2
# fighting    2600       6
# fire        9997       3
# flying      3920       2
# ghost       3300       3
# grass        925       3
# ground      7400       4
# ice         3250       3
# normal       815       5
# poison      2005       2
# psychic     9429       3
# rock        3600       3
# steel       4300       3
# water       1950       3

# %% [markdown]
# ### Filtering
# A filtering operation allows you to drop data based on the group properties.

# %%
#returns only pokemons whose standard deviation of its height is greater than 150.
def func(x):
    return x['height'].std() > 150
display(poke_data.groupby('type_2').filter(func))
# Out:
#         id         pokemon  species_id  height  weight  base_experience  \
# 30      31       nidoqueen          31      13     600              227
# 33      34        nidoking          34      14     620              227
# 73      74         geodude          74       4     200               60
# 74      75        graveler          75      10    1050              137
# 75      76           golem          76      14    3000              223
# 94      95            onix          95      88    2100               77
# 193    194          wooper         194       4      85               42
# 194    195        quagsire         195      14     750              151
# 207    208         steelix         208      92    4000              179
# 219    220          swinub         220       4      65               50
# 220    221       piloswine         221      11     558              158
# 245    246        larvitar         246       6     720               60
# ...

# %% [markdown]
# ## Handling Missing Data

# %%
# dropping two columns which has more missing elements
poke_data.drop(['evolves_from_species_id','egg_group_2'],axis=1,inplace=True)

poke_data.head()
# Out:
#    id     pokemon  species_id  height  weight  base_experience type_1  type_2  \
# 0   1   bulbasaur           1       7      69               64  grass  poison
# 1   2     ivysaur           2      10     130              142  grass  poison
# 2   3    venusaur           3      20    1000              236  grass  poison
# 3   4  charmander           4       6      85               62   fire     NaN
# 4   5  charmeleon           5      11     190              142   fire     NaN
#
#    attack  defense    ...      ability_hidden  color_1  color_2  color_f  \
# 0      49       49    ...         chlorophyll  #78C850  #A040A0  #81A763
# 1      62       63    ...         chlorophyll  #78C850  #A040A0  #81A763
# 2      82       83    ...         chlorophyll  #78C850  #A040A0  #81A763
# 3      52       43    ...         solar-power  #F08030      NaN      NaN
# 4      64       58    ...         solar-power  #F08030      NaN      NaN
#
# ...

# %%
#filling missing values in type_2 and ability_2
values = {'type_2': 'No Type', 'ability_2' : 'Unknown'}
poke_data.fillna(value= values,inplace=True)
poke_data.head()
# Out:
#    id     pokemon  species_id  height  weight  base_experience type_1  \
# 0   1   bulbasaur           1       7      69               64  grass
# 1   2     ivysaur           2      10     130              142  grass
# 2   3    venusaur           3      20    1000              236  grass
# 3   4  charmander           4       6      85               62   fire
# 4   5  charmeleon           5      11     190              142   fire
#
#     type_2  attack  defense    ...      ability_hidden  color_1  color_2  \
# 0   poison      49       49    ...         chlorophyll  #78C850  #A040A0
# 1   poison      62       63    ...         chlorophyll  #78C850  #A040A0
# 2   poison      82       83    ...         chlorophyll  #78C850  #A040A0
# 3  No Type      52       43    ...         solar-power  #F08030      NaN
# 4  No Type      64       58    ...         solar-power  #F08030      NaN
#
#    color_f egg_group_1 url_image generation_id evolution_chain_id shape_id  \
# ...

# %% [markdown]
# ## Reference
#
# [1] https://www.kaggle.com/davidrgp/pokedex
# [2] https://pandas.pydata.org/
# [3] https://www.python-course.eu/matrix_arithmetic.php
